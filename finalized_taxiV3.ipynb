# %% [markdown]
# <a href="https://colab.research.google.com/github/mikohuhu/q-learning-taxi-v3-MMAI845/blob/JAY/finalized_taxiV3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gym
import numpy as np
import time
import pandas as pd

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# %%
# Initialize Taxi-v3 environment
env = gym.make('Taxi-v3')

# %%
#The first code implements a sampling method where actions are randomly selected at each timestep without any learning involved.
#This is akin to a brute-force approach, where actions are chosen without regard to the state or any learned policies.

def evaluate_sampling_method(num_episodes=100):
    penalties = []
    timesteps = []
    rewards = []

    for _ in range(num_episodes):
        state = env.reset()
        episode_penalties = 0
        episode_timesteps = 0
        episode_rewards = 0

        done = False
        while not done:
            # Sample a random action
            action = env.action_space.sample()

            # Perform the action
            next_state, reward, done, _ = env.step(action)

            # Update episode statistics
            episode_penalties += 1 if reward == -10 else 0
            episode_timesteps += 1
            episode_rewards += reward

            state = next_state

        penalties.append(episode_penalties)
        timesteps.append(episode_timesteps)
        rewards.append(episode_rewards)

    # Calculate metrics
    avg_penalties = np.mean(penalties)
    avg_timesteps = np.mean(timesteps)
    avg_rewards = np.mean(rewards)

    return avg_penalties, avg_timesteps, avg_rewards

# Perform the experiment and measure the execution time
start_time = time.time()
avg_penalties, avg_timesteps, avg_rewards = evaluate_sampling_method()
end_time = time.time()
execution_time = end_time - start_time

# Print metrics
print("Experiment 1: Sampling Method")
print("Average number of penalties per episode:", avg_penalties)
print("Average number of timesteps per trip:", avg_timesteps)
print("Average rewards per move:", avg_rewards)
print("Total time to execute:", execution_time, "seconds")
# Out:
# Experiment 1: Sampling Method
# Average number of penalties per episode: 64.2
# Average number of timesteps per trip: 195.88
# Average rewards per move: -772.42
# Total time to execute: 0.8409316539764404 seconds

# %%
env = gym.make('Taxi-v3')

def q_learning(env, num_episodes=100000, alpha=0.1, gamma=0.6, epsilon=0.1):
    Q = np.zeros((env.observation_space.n, env.action_space.n))

    total_penalties = 0
    total_timesteps = 0
    total_rewards = 0

    start_time = time.time()  # Start time

    for episode in range(num_episodes):
        state = env.reset()
        episode_penalties = 0
        episode_timesteps = 0
        episode_rewards = 0

        done = False
        while not done:
            # Epsilon-greedy action selection
            if np.random.uniform(0, 1) < epsilon:
                action = env.action_space.sample()  # Exploration
            else:
                action = np.argmax(Q[state])  # Exploitation

            next_state, reward, done, _ = env.step(action)

            # Q-Learning update
            best_next_action = np.argmax(Q[next_state])
            Q[state, action] += alpha * (reward + gamma * Q[next_state, best_next_action] - Q[state, action])

            # Update episode statistics
            episode_penalties += 1 if reward == -10 else 0
            episode_timesteps += 1
            episode_rewards += reward

            state = next_state

        total_penalties += episode_penalties
        total_timesteps += episode_timesteps
        total_rewards += episode_rewards

    # Calculate metrics
    avg_penalties = total_penalties / num_episodes
    avg_timesteps = total_timesteps / num_episodes
    avg_rewards = total_rewards / (total_timesteps - total_penalties)  # Average rewards per move

    end_time = time.time()  # End time
    execution_time = end_time - start_time  # Calculate execution time

    return avg_penalties, avg_timesteps, avg_rewards, execution_time

# Perform Q-Learning experiment
avg_penalties, avg_timesteps, avg_rewards, execution_time = q_learning(env)

# Print metrics
print("Experiment 2: Q-Learning")
print("Average number of penalties per episode:", avg_penalties)
print("Average number of timesteps per trip:", avg_timesteps)
print("Average rewards per move:", avg_rewards)
print("Total time to train:", execution_time, "seconds")
# Out:
# Experiment 2: Q-Learning
# Average number of penalties per episode: 0.48125
# Average number of timesteps per trip: 15.89639
# Average rewards per move: 0.046793606804738715
# Total time to train: 69.6101667881012 seconds

# %%
def sarsa(env, num_episodes=100000, alpha=0.2, gamma=0.8, epsilon=0.1):
    Q = np.zeros((env.observation_space.n, env.action_space.n))

    total_penalties = 0
    total_timesteps = 0
    total_rewards = 0

    start_time = time.time()  # Start time

    for episode in range(num_episodes):
        state = env.reset()
        action = epsilon_greedy_policy(Q, state, epsilon)

        episode_penalties = 0
        episode_timesteps = 0
        episode_rewards = 0

        done = False
        while not done:
            next_state, reward, done, _ = env.step(action)
            next_action = epsilon_greedy_policy(Q, next_state, epsilon)

            # SARSA update
            Q[state, action] += alpha * (reward + gamma * Q[next_state, next_action] - Q[state, action])

            # Update episode statistics
            episode_penalties += 1 if reward == -10 else 0
            episode_timesteps += 1
            episode_rewards += reward

            state = next_state
            action = next_action

        total_penalties += episode_penalties
        total_timesteps += episode_timesteps
        total_rewards += episode_rewards

    # Calculate metrics
    avg_penalties = total_penalties / num_episodes
    avg_timesteps = total_timesteps / num_episodes
    avg_rewards = total_rewards / (total_timesteps - total_penalties)  # Average rewards per move

    end_time = time.time()  # End time
    execution_time = end_time - start_time  # Calculate execution time

    return avg_penalties, avg_timesteps, avg_rewards, execution_time

def epsilon_greedy_policy(Q, state, epsilon):
    if np.random.uniform(0, 1) < epsilon:
        return np.random.choice(env.action_space.n)  # Exploration
    else:
        return np.argmax(Q[state])  # Exploitation

# Perform SARSA experiment
avg_penalties, avg_timesteps, avg_rewards, execution_time = sarsa(env)

# Print metrics
print("Experiment 3: SARSA")
print("Average number of penalties per episode:", avg_penalties)
print("Average number of timesteps per trip:", avg_timesteps)
print("Average rewards per move:", avg_rewards)
print("Total time to train:", execution_time, "seconds")
# Out:
# Experiment 3: SARSA
# Average number of penalties per episode: 0.90008
# Average number of timesteps per trip: 28.31204
# Average rewards per move: -0.5942176334709375
# Total time to train: 120.70162725448608 seconds

# %%
import numpy as np
import time
from keras.optimizers import Adam
import gym
from keras.models import Sequential
from keras.layers import Dense, Embedding, Reshape
from collections import deque
import random
from tqdm import tqdm  # Importing tqdm for progress bar

# Initialize the environment with the new step API
env_taxi = gym.make("Taxi-v3", new_step_api=True).env

class TaxiAgent:
    def __init__(self, env, optimizer):
        self._state_size = env.observation_space.n
        self._action_size = env.action_space.n
        self._optimizer = optimizer
        self.experience_replay_memory = deque(maxlen=2000)
        self.discount = 0.6
        self.exploration = 0.1
        self.q_network = self._build_compile_model()
        self.target_network = self._build_compile_model()
        self.align_both_model()

    def gather(self, state, action, reward, next_state, terminated):
        self.experience_replay_memory.append((state, action, reward, next_state, terminated))

    def _build_compile_model(self):
        model = Sequential()
        model.add(Embedding(self._state_size, 10, input_length=1))
        model.add(Reshape((10,)))
        model.add(Dense(50, activation='relu'))
        model.add(Dense(50, activation='relu'))
        model.add(Dense(self._action_size, activation='linear'))
        model.compile(loss='mse', optimizer=self._optimizer)
        return model

    def align_both_model(self):
        self.target_network.set_weights(self.q_network.get_weights())

    def act(self, state):
        if np.random.rand() <= self.exploration:
            return env_taxi.action_space.sample()
        q_values = self.q_network.predict(state, verbose=0)
        return np.argmax(q_values[0])

    def retrain(self, batch_size):
        minibatch = random.sample(self.experience_replay_memory, batch_size)
        for state, action, reward, next_state, terminated in minibatch:
            target = self.q_network.predict(state, verbose=0)
            if terminated:
                target[0][action] = reward
            else:
                t = self.target_network.predict(next_state, verbose=0)
                target[0][action] = reward + self.discount * np.amax(t)
            self.q_network.fit(state, target, epochs=1, verbose=0)  # Reduce the epochs

def deep_q_learning(env, num_training_episodes=100, num_evaluation_episodes=100, alpha=0.01, gamma=0.6, epsilon=0.1, batch_size=32, timesteps_per_episode=40, epochs=4):
    # Training phase
    start_time = time.time()  # Record start time for training
    total_penalties = 0
    total_timesteps = 0
    total_rewards = 0

    for e in tqdm(range(num_training_episodes), desc="Training Episodes"):
        state = env_taxi.reset()
        state = np.reshape(state, [1, 1])
        reward = 0
        terminated = False
        timesteps = 0
        penalties = 0

        while not terminated and timesteps < timesteps_per_episode:
            action = taxi_agent.act(state)
            next_state, reward, terminated, truncated, info = env_taxi.step(action)
            next_state = np.reshape(next_state, [1, 1])
            taxi_agent.gather(state, action, reward, next_state, terminated)
            state = next_state
            timesteps += 1
            if reward == -10:
                penalties += 1

            # Debugging print statements
            print(f"Episode {e + 1}, Timestep {timesteps}: action={action}, reward={reward}, terminated={terminated}, penalties={penalties}")

            if len(taxi_agent.experience_replay_memory) > batch_size and timesteps % 10 == 0:  # Retrain less frequently
                print(f"Retraining on mini-batch at episode {e + 1}")
                taxi_agent.retrain(batch_size)

        total_penalties += penalties
        total_timesteps += timesteps
        total_rewards += reward

    end_time = time.time()  # Record end time for training
    execution_time = end_time - start_time  # Calculate time to train

    # Evaluation phase
    total_penalties = 0
    total_timesteps = 0
    total_rewards = 0
    for e in tqdm(range(num_evaluation_episodes), desc="Evaluation Episodes"):
        # Evaluation episode loop
        state = env_taxi.reset()
        state = np.reshape(state, [1, 1])
        reward = 0
        terminated = False
        timesteps = 0
        penalties = 0

        while not terminated and timesteps < timesteps_per_episode:
            action = taxi_agent.act(state)
            next_state, reward, terminated, truncated, info = env_taxi.step(action)
            next_state = np.reshape(next_state, [1, 1])
            state = next_state
            timesteps += 1
            if reward == -10:
                penalties += 1

            # Debugging print statements
            print(f"Evaluation Episode {e + 1}, Timestep {timesteps}: action={action}, reward={reward}, terminated={terminated}, penalties={penalties}")

        total_penalties += penalties
        total_timesteps += timesteps
        total_rewards += reward

    # Calculate averages for evaluation metrics
    average_penalties = total_penalties / num_evaluation_episodes
    average_timesteps = total_timesteps / num_evaluation_episodes
    average_rewards_per_move = total_rewards / (total_timesteps - total_penalties)

    # Print metrics
    print("Deep Q-Learning Method:")
    print("Average number of penalties per episode:", average_penalties)
    print("Average number of timesteps per trip:", average_timesteps)
    print("Average rewards per move:", average_rewards_per_move)
    print("Time to train:", execution_time, "seconds")

# Creating the optimizer
optimizer = Adam(learning_rate=0.01)

# Creating the TaxiAgent instance
taxi_agent = TaxiAgent(env_taxi, optimizer)

# Defining parameters for the experiment
num_training_episodes = 100
num_evaluation_episodes = 100
batch_size = 32
timesteps_per_episode = 40

# Running the Deep Q-Learning experiment
deep_q_learning(env_taxi, num_training_episodes, num_evaluation_episodes, batch_size=batch_size, timesteps_per_episode=timesteps_per_episode)
# Out:
# Training Episodes:   0%|          | 0/100 [00:00<?, ?it/s]
# Episode 1, Timestep 1: action=1, reward=-1, terminated=False, penalties=0
# Episode 1, Timestep 2: action=1, reward=-1, terminated=False, penalties=0
# Episode 1, Timestep 3: action=1, reward=-1, terminated=False, penalties=0
# Episode 1, Timestep 4: action=3, reward=-1, terminated=False, penalties=0
# Episode 1, Timestep 5: action=3, reward=-1, terminated=False, penalties=0
# Episode 1, Timestep 6: action=4, reward=-10, terminated=False, penalties=1
# Episode 1, Timestep 7: action=3, reward=-1, terminated=False, penalties=1
# Episode 1, Timestep 8: action=3, reward=-1, terminated=False, penalties=1
# Episode 1, Timestep 9: action=3, reward=-1, terminated=False, penalties=1
# Episode 1, Timestep 10: action=3, reward=-1, terminated=False, penalties=1
# Episode 1, Timestep 11: action=3, reward=-1, terminated=False, penalties=1
# Episode 1, Timestep 12: action=3, reward=-1, terminated=False, penalties=1
# Episode 1, Timestep 13: action=3, reward=-1, terminated=False, penalties=1
# Episode 1, Timestep 14: action=3, reward=-1, terminated=False, penalties=1
# Episode 1, Timestep 15: action=3, reward=-1, terminated=False, penalties=1
# Episode 1, Timestep 16: action=3, reward=-1, terminated=False, penalties=1
# Episode 1, Timestep 17: action=3, reward=-1, terminated=False, penalties=1
# Episode 1, Timestep 18: action=3, reward=-1, terminated=False, penalties=1
# Episode 1, Timestep 19: action=3, reward=-1, terminated=False, penalties=1
# Episode 1, Timestep 20: action=3, reward=-1, terminated=False, penalties=1
# Episode 1, Timestep 21: action=3, reward=-1, terminated=False, penalties=1
# Episode 1, Timestep 22: action=0, reward=-1, terminated=False, penalties=1
# Episode 1, Timestep 23: action=1, reward=-1, terminated=False, penalties=1
# Episode 1, Timestep 24: action=3, reward=-1, terminated=False, penalties=1
# Episode 1, Timestep 25: action=3, reward=-1, terminated=False, penalties=1
# Episode 1, Timestep 26: action=3, reward=-1, terminated=False, penalties=1
# Episode 1, Timestep 27: action=3, reward=-1, terminated=False, penalties=1
# Episode 1, Timestep 28: action=3, reward=-1, terminated=False, penalties=1
# Episode 1, Timestep 29: action=3, reward=-1, terminated=False, penalties=1
# Episode 1, Timestep 30: action=3, reward=-1, terminated=False, penalties=1
# Episode 1, Timestep 31: action=3, reward=-1, terminated=False, penalties=1
# Episode 1, Timestep 32: action=3, reward=-1, terminated=False, penalties=1
# Episode 1, Timestep 33: action=3, reward=-1, terminated=False, penalties=1
# Episode 1, Timestep 34: action=3, reward=-1, terminated=False, penalties=1
# Episode 1, Timestep 35: action=3, reward=-1, terminated=False, penalties=1
# Episode 1, Timestep 36: action=0, reward=-1, terminated=False, penalties=1
# Episode 1, Timestep 37: action=1, reward=-1, terminated=False, penalties=1
# Episode 1, Timestep 38: action=3, reward=-1, terminated=False, penalties=1
# Episode 1, Timestep 39: action=3, reward=-1, terminated=False, penalties=1
# Episode 1, Timestep 40: action=3, reward=-1, terminated=False, penalties=1
# Retraining on mini-batch at episode 1
# Training Episodes:   1%|          | 1/100 [00:11<19:02, 11.54s/it]
# Episode 2, Timestep 1: action=5, reward=-10, terminated=False, penalties=1
# Episode 2, Timestep 2: action=5, reward=-10, terminated=False, penalties=2
# Episode 2, Timestep 3: action=5, reward=-10, terminated=False, penalties=3
# Episode 2, Timestep 4: action=5, reward=-10, terminated=False, penalties=4
# Episode 2, Timestep 5: action=5, reward=-10, terminated=False, penalties=5
# Episode 2, Timestep 6: action=5, reward=-10, terminated=False, penalties=6
# Episode 2, Timestep 7: action=5, reward=-10, terminated=False, penalties=7
# Episode 2, Timestep 8: action=5, reward=-10, terminated=False, penalties=8
# Episode 2, Timestep 9: action=5, reward=-10, terminated=False, penalties=9
# Episode 2, Timestep 10: action=5, reward=-10, terminated=False, penalties=10
# Retraining on mini-batch at episode 2
# Episode 2, Timestep 11: action=2, reward=-1, terminated=False, penalties=10
# Episode 2, Timestep 12: action=2, reward=-1, terminated=False, penalties=10
# Episode 2, Timestep 13: action=2, reward=-1, terminated=False, penalties=10
# Episode 2, Timestep 14: action=2, reward=-1, terminated=False, penalties=10
# Episode 2, Timestep 15: action=2, reward=-1, terminated=False, penalties=10
# Episode 2, Timestep 16: action=2, reward=-1, terminated=False, penalties=10
# Episode 2, Timestep 17: action=4, reward=-10, terminated=False, penalties=11
# Episode 2, Timestep 18: action=3, reward=-1, terminated=False, penalties=11
# Episode 2, Timestep 19: action=5, reward=-10, terminated=False, penalties=12
# Episode 2, Timestep 20: action=2, reward=-1, terminated=False, penalties=12
# Retraining on mini-batch at episode 2
# Episode 2, Timestep 21: action=0, reward=-1, terminated=False, penalties=12
# Episode 2, Timestep 22: action=1, reward=-1, terminated=False, penalties=12
# Episode 2, Timestep 23: action=1, reward=-1, terminated=False, penalties=12
# Episode 2, Timestep 24: action=1, reward=-1, terminated=False, penalties=12
# Episode 2, Timestep 25: action=1, reward=-1, terminated=False, penalties=12
# Episode 2, Timestep 26: action=1, reward=-1, terminated=False, penalties=12
# Episode 2, Timestep 27: action=1, reward=-1, terminated=False, penalties=12
# Episode 2, Timestep 28: action=1, reward=-1, terminated=False, penalties=12
# Episode 2, Timestep 29: action=1, reward=-1, terminated=False, penalties=12
# Episode 2, Timestep 30: action=1, reward=-1, terminated=False, penalties=12
# Retraining on mini-batch at episode 2
# Episode 2, Timestep 31: action=2, reward=-1, terminated=False, penalties=12
# Episode 2, Timestep 32: action=4, reward=-1, terminated=False, penalties=12
# Episode 2, Timestep 33: action=0, reward=-1, terminated=False, penalties=12
# Episode 2, Timestep 34: action=0, reward=-1, terminated=False, penalties=12
# Episode 2, Timestep 35: action=1, reward=-1, terminated=False, penalties=12
# Episode 2, Timestep 36: action=0, reward=-1, terminated=False, penalties=12
# Episode 2, Timestep 37: action=0, reward=-1, terminated=False, penalties=12
# Episode 2, Timestep 38: action=0, reward=-1, terminated=False, penalties=12
# Episode 2, Timestep 39: action=0, reward=-1, terminated=False, penalties=12
# Episode 2, Timestep 40: action=0, reward=-1, terminated=False, penalties=12
# Retraining on mini-batch at episode 2
# Training Episodes:   2%|▏         | 2/100 [00:48<43:05, 26.38s/it]
# Episode 3, Timestep 1: action=3, reward=-1, terminated=False, penalties=0
# Episode 3, Timestep 2: action=3, reward=-1, terminated=False, penalties=0
# Episode 3, Timestep 3: action=3, reward=-1, terminated=False, penalties=0
# Episode 3, Timestep 4: action=3, reward=-1, terminated=False, penalties=0
# Episode 3, Timestep 5: action=2, reward=-1, terminated=False, penalties=0
# Episode 3, Timestep 6: action=3, reward=-1, terminated=False, penalties=0
# Episode 3, Timestep 7: action=3, reward=-1, terminated=False, penalties=0
# Episode 3, Timestep 8: action=3, reward=-1, terminated=False, penalties=0
# Episode 3, Timestep 9: action=0, reward=-1, terminated=False, penalties=0
# Episode 3, Timestep 10: action=3, reward=-1, terminated=False, penalties=0
# Retraining on mini-batch at episode 3
# Episode 3, Timestep 11: action=3, reward=-1, terminated=False, penalties=0
# Episode 3, Timestep 12: action=0, reward=-1, terminated=False, penalties=0
# Episode 3, Timestep 13: action=0, reward=-1, terminated=False, penalties=0
# Episode 3, Timestep 14: action=0, reward=-1, terminated=False, penalties=0
# Episode 3, Timestep 15: action=0, reward=-1, terminated=False, penalties=0
# Episode 3, Timestep 16: action=0, reward=-1, terminated=False, penalties=0
# Episode 3, Timestep 17: action=0, reward=-1, terminated=False, penalties=0
# Episode 3, Timestep 18: action=0, reward=-1, terminated=False, penalties=0
# Episode 3, Timestep 19: action=0, reward=-1, terminated=False, penalties=0
# Episode 3, Timestep 20: action=0, reward=-1, terminated=False, penalties=0
# Retraining on mini-batch at episode 3
# Episode 3, Timestep 21: action=3, reward=-1, terminated=False, penalties=0
# Episode 3, Timestep 22: action=3, reward=-1, terminated=False, penalties=0
# Episode 3, Timestep 23: action=3, reward=-1, terminated=False, penalties=0
# Episode 3, Timestep 24: action=3, reward=-1, terminated=False, penalties=0
# Episode 3, Timestep 25: action=3, reward=-1, terminated=False, penalties=0
# Episode 3, Timestep 26: action=3, reward=-1, terminated=False, penalties=0
# Episode 3, Timestep 27: action=0, reward=-1, terminated=False, penalties=0
# Episode 3, Timestep 28: action=3, reward=-1, terminated=False, penalties=0
# Episode 3, Timestep 29: action=3, reward=-1, terminated=False, penalties=0
# Episode 3, Timestep 30: action=3, reward=-1, terminated=False, penalties=0
# Retraining on mini-batch at episode 3
# Episode 3, Timestep 31: action=3, reward=-1, terminated=False, penalties=0
# Episode 3, Timestep 32: action=3, reward=-1, terminated=False, penalties=0
# Episode 3, Timestep 33: action=3, reward=-1, terminated=False, penalties=0
# Episode 3, Timestep 34: action=3, reward=-1, terminated=False, penalties=0
# Episode 3, Timestep 35: action=3, reward=-1, terminated=False, penalties=0
# Episode 3, Timestep 36: action=3, reward=-1, terminated=False, penalties=0
# Episode 3, Timestep 37: action=3, reward=-1, terminated=False, penalties=0
# Episode 3, Timestep 38: action=3, reward=-1, terminated=False, penalties=0
# Episode 3, Timestep 39: action=3, reward=-1, terminated=False, penalties=0
# Episode 3, Timestep 40: action=3, reward=-1, terminated=False, penalties=0
# Retraining on mini-batch at episode 3
# Training Episodes:   3%|▎         | 3/100 [01:22<48:46, 30.17s/it]
# Episode 4, Timestep 1: action=2, reward=-1, terminated=False, penalties=0
# Episode 4, Timestep 2: action=2, reward=-1, terminated=False, penalties=0
# Episode 4, Timestep 3: action=2, reward=-1, terminated=False, penalties=0
# Episode 4, Timestep 4: action=2, reward=-1, terminated=False, penalties=0
# Episode 4, Timestep 5: action=2, reward=-1, terminated=False, penalties=0
# Episode 4, Timestep 6: action=2, reward=-1, terminated=False, penalties=0
# Episode 4, Timestep 7: action=2, reward=-1, terminated=False, penalties=0
# Episode 4, Timestep 8: action=2, reward=-1, terminated=False, penalties=0
# Episode 4, Timestep 9: action=2, reward=-1, terminated=False, penalties=0
# Episode 4, Timestep 10: action=2, reward=-1, terminated=False, penalties=0
# Retraining on mini-batch at episode 4
# Episode 4, Timestep 11: action=5, reward=-10, terminated=False, penalties=1
# Episode 4, Timestep 12: action=3, reward=-1, terminated=False, penalties=1
# Episode 4, Timestep 13: action=3, reward=-1, terminated=False, penalties=1
# Episode 4, Timestep 14: action=3, reward=-1, terminated=False, penalties=1
# Episode 4, Timestep 15: action=3, reward=-1, terminated=False, penalties=1
# Episode 4, Timestep 16: action=3, reward=-1, terminated=False, penalties=1
# Episode 4, Timestep 17: action=3, reward=-1, terminated=False, penalties=1
# Episode 4, Timestep 18: action=3, reward=-1, terminated=False, penalties=1
# Episode 4, Timestep 19: action=3, reward=-1, terminated=False, penalties=1
# Episode 4, Timestep 20: action=3, reward=-1, terminated=False, penalties=1
# Retraining on mini-batch at episode 4
# Episode 4, Timestep 21: action=0, reward=-1, terminated=False, penalties=1
# Episode 4, Timestep 22: action=5, reward=-10, terminated=False, penalties=2
# Episode 4, Timestep 23: action=3, reward=-1, terminated=False, penalties=2
# Episode 4, Timestep 24: action=3, reward=-1, terminated=False, penalties=2
# Episode 4, Timestep 25: action=3, reward=-1, terminated=False, penalties=2
# Episode 4, Timestep 26: action=3, reward=-1, terminated=False, penalties=2
# Episode 4, Timestep 27: action=3, reward=-1, terminated=False, penalties=2
# Episode 4, Timestep 28: action=3, reward=-1, terminated=False, penalties=2
# Episode 4, Timestep 29: action=3, reward=-1, terminated=False, penalties=2
# Episode 4, Timestep 30: action=3, reward=-1, terminated=False, penalties=2
# Retraining on mini-batch at episode 4
# Episode 4, Timestep 31: action=1, reward=-1, terminated=False, penalties=2
# Episode 4, Timestep 32: action=1, reward=-1, terminated=False, penalties=2
# Episode 4, Timestep 33: action=0, reward=-1, terminated=False, penalties=2
# Episode 4, Timestep 34: action=1, reward=-1, terminated=False, penalties=2
# Episode 4, Timestep 35: action=0, reward=-1, terminated=False, penalties=2
# Episode 4, Timestep 36: action=1, reward=-1, terminated=False, penalties=2
# Episode 4, Timestep 37: action=2, reward=-1, terminated=False, penalties=2
# Episode 4, Timestep 38: action=0, reward=-1, terminated=False, penalties=2
# Episode 4, Timestep 39: action=1, reward=-1, terminated=False, penalties=2
# Episode 4, Timestep 40: action=0, reward=-1, terminated=False, penalties=2
# Retraining on mini-batch at episode 4
# Training Episodes:   4%|▍         | 4/100 [01:59<52:25, 32.76s/it]
# Episode 5, Timestep 1: action=3, reward=-1, terminated=False, penalties=0
# Episode 5, Timestep 2: action=3, reward=-1, terminated=False, penalties=0
# Episode 5, Timestep 3: action=3, reward=-1, terminated=False, penalties=0
# Episode 5, Timestep 4: action=3, reward=-1, terminated=False, penalties=0
# Episode 5, Timestep 5: action=3, reward=-1, terminated=False, penalties=0
# Episode 5, Timestep 6: action=3, reward=-1, terminated=False, penalties=0
# Episode 5, Timestep 7: action=3, reward=-1, terminated=False, penalties=0
# Episode 5, Timestep 8: action=3, reward=-1, terminated=False, penalties=0
# Episode 5, Timestep 9: action=3, reward=-1, terminated=False, penalties=0
# Episode 5, Timestep 10: action=3, reward=-1, terminated=False, penalties=0
# Retraining on mini-batch at episode 5
# Episode 5, Timestep 11: action=0, reward=-1, terminated=False, penalties=0
# Episode 5, Timestep 12: action=2, reward=-1, terminated=False, penalties=0
# Episode 5, Timestep 13: action=2, reward=-1, terminated=False, penalties=0
# Episode 5, Timestep 14: action=2, reward=-1, terminated=False, penalties=0
# Episode 5, Timestep 15: action=2, reward=-1, terminated=False, penalties=0
# Episode 5, Timestep 16: action=2, reward=-1, terminated=False, penalties=0
# Episode 5, Timestep 17: action=2, reward=-1, terminated=False, penalties=0
# Episode 5, Timestep 18: action=2, reward=-1, terminated=False, penalties=0
# Episode 5, Timestep 19: action=2, reward=-1, terminated=False, penalties=0
# Episode 5, Timestep 20: action=2, reward=-1, terminated=False, penalties=0
# Retraining on mini-batch at episode 5
# Episode 5, Timestep 21: action=0, reward=-1, terminated=False, penalties=0
# Episode 5, Timestep 22: action=0, reward=-1, terminated=False, penalties=0
# Episode 5, Timestep 23: action=0, reward=-1, terminated=False, penalties=0
# Episode 5, Timestep 24: action=0, reward=-1, terminated=False, penalties=0
# Episode 5, Timestep 25: action=0, reward=-1, terminated=False, penalties=0
# Episode 5, Timestep 26: action=0, reward=-1, terminated=False, penalties=0
# Episode 5, Timestep 27: action=0, reward=-1, terminated=False, penalties=0
# Episode 5, Timestep 28: action=0, reward=-1, terminated=False, penalties=0
# Episode 5, Timestep 29: action=0, reward=-1, terminated=False, penalties=0
# Episode 5, Timestep 30: action=0, reward=-1, terminated=False, penalties=0
# Retraining on mini-batch at episode 5
# Episode 5, Timestep 31: action=1, reward=-1, terminated=False, penalties=0
# Episode 5, Timestep 32: action=1, reward=-1, terminated=False, penalties=0
# Episode 5, Timestep 33: action=3, reward=-1, terminated=False, penalties=0
# Episode 5, Timestep 34: action=1, reward=-1, terminated=False, penalties=0
# Episode 5, Timestep 35: action=1, reward=-1, terminated=False, penalties=0
# Episode 5, Timestep 36: action=1, reward=-1, terminated=False, penalties=0
# Episode 5, Timestep 37: action=1, reward=-1, terminated=False, penalties=0
# Episode 5, Timestep 38: action=1, reward=-1, terminated=False, penalties=0
# Episode 5, Timestep 39: action=3, reward=-1, terminated=False, penalties=0
# Episode 5, Timestep 40: action=1, reward=-1, terminated=False, penalties=0
# Retraining on mini-batch at episode 5
# Training Episodes:   5%|▌         | 5/100 [02:35<53:49, 33.99s/it]
# Episode 6, Timestep 1: action=1, reward=-1, terminated=False, penalties=0
# Episode 6, Timestep 2: action=3, reward=-1, terminated=False, penalties=0
# Episode 6, Timestep 3: action=1, reward=-1, terminated=False, penalties=0
# Episode 6, Timestep 4: action=1, reward=-1, terminated=False, penalties=0
# Episode 6, Timestep 5: action=1, reward=-1, terminated=False, penalties=0
# Episode 6, Timestep 6: action=1, reward=-1, terminated=False, penalties=0
# Episode 6, Timestep 7: action=1, reward=-1, terminated=False, penalties=0
# Episode 6, Timestep 8: action=1, reward=-1, terminated=False, penalties=0
# Episode 6, Timestep 9: action=1, reward=-1, terminated=False, penalties=0
# Episode 6, Timestep 10: action=1, reward=-1, terminated=False, penalties=0
# Retraining on mini-batch at episode 6
# Episode 6, Timestep 11: action=5, reward=-10, terminated=False, penalties=1
# Episode 6, Timestep 12: action=1, reward=-1, terminated=False, penalties=1
# Episode 6, Timestep 13: action=1, reward=-1, terminated=False, penalties=1
# Episode 6, Timestep 14: action=1, reward=-1, terminated=False, penalties=1
# Episode 6, Timestep 15: action=1, reward=-1, terminated=False, penalties=1
# Episode 6, Timestep 16: action=1, reward=-1, terminated=False, penalties=1
# Episode 6, Timestep 17: action=1, reward=-1, terminated=False, penalties=1
# Episode 6, Timestep 18: action=1, reward=-1, terminated=False, penalties=1
# Episode 6, Timestep 19: action=1, reward=-1, terminated=False, penalties=1
# Episode 6, Timestep 20: action=1, reward=-1, terminated=False, penalties=1
# Retraining on mini-batch at episode 6
# Episode 6, Timestep 21: action=0, reward=-1, terminated=False, penalties=1
# Episode 6, Timestep 22: action=0, reward=-1, terminated=False, penalties=1
# Episode 6, Timestep 23: action=0, reward=-1, terminated=False, penalties=1
# Episode 6, Timestep 24: action=0, reward=-1, terminated=False, penalties=1
# Episode 6, Timestep 25: action=0, reward=-1, terminated=False, penalties=1
# Episode 6, Timestep 26: action=0, reward=-1, terminated=False, penalties=1
# Episode 6, Timestep 27: action=4, reward=-10, terminated=False, penalties=2
# Episode 6, Timestep 28: action=0, reward=-1, terminated=False, penalties=2
# Episode 6, Timestep 29: action=0, reward=-1, terminated=False, penalties=2
# Episode 6, Timestep 30: action=0, reward=-1, terminated=False, penalties=2
# Retraining on mini-batch at episode 6
# Episode 6, Timestep 31: action=2, reward=-1, terminated=False, penalties=2
# Episode 6, Timestep 32: action=1, reward=-1, terminated=False, penalties=2
# Episode 6, Timestep 33: action=2, reward=-1, terminated=False, penalties=2
# Episode 6, Timestep 34: action=2, reward=-1, terminated=False, penalties=2
# Episode 6, Timestep 35: action=2, reward=-1, terminated=False, penalties=2
# Episode 6, Timestep 36: action=2, reward=-1, terminated=False, penalties=2
# Episode 6, Timestep 37: action=2, reward=-1, terminated=False, penalties=2
# Episode 6, Timestep 38: action=2, reward=-1, terminated=False, penalties=2
# Episode 6, Timestep 39: action=2, reward=-1, terminated=False, penalties=2
# Episode 6, Timestep 40: action=2, reward=-1, terminated=False, penalties=2
# Retraining on mini-batch at episode 6
# Training Episodes:   6%|▌         | 6/100 [03:09<53:13, 33.98s/it]
# Episode 7, Timestep 1: action=2, reward=-1, terminated=False, penalties=0
# Episode 7, Timestep 2: action=2, reward=-1, terminated=False, penalties=0
# Episode 7, Timestep 3: action=2, reward=-1, terminated=False, penalties=0
# Episode 7, Timestep 4: action=2, reward=-1, terminated=False, penalties=0
# Episode 7, Timestep 5: action=2, reward=-1, terminated=False, penalties=0
# Episode 7, Timestep 6: action=2, reward=-1, terminated=False, penalties=0
# Episode 7, Timestep 7: action=2, reward=-1, terminated=False, penalties=0
# Episode 7, Timestep 8: action=2, reward=-1, terminated=False, penalties=0
# Episode 7, Timestep 9: action=1, reward=-1, terminated=False, penalties=0
# Episode 7, Timestep 10: action=2, reward=-1, terminated=False, penalties=0
# Retraining on mini-batch at episode 7
# Episode 7, Timestep 11: action=2, reward=-1, terminated=False, penalties=0
# Episode 7, Timestep 12: action=2, reward=-1, terminated=False, penalties=0
# Episode 7, Timestep 13: action=3, reward=-1, terminated=False, penalties=0
# Episode 7, Timestep 14: action=2, reward=-1, terminated=False, penalties=0
# Episode 7, Timestep 15: action=2, reward=-1, terminated=False, penalties=0
# Episode 7, Timestep 16: action=2, reward=-1, terminated=False, penalties=0
# Episode 7, Timestep 17: action=2, reward=-1, terminated=False, penalties=0
# Episode 7, Timestep 18: action=2, reward=-1, terminated=False, penalties=0
# Episode 7, Timestep 19: action=2, reward=-1, terminated=False, penalties=0
# Episode 7, Timestep 20: action=2, reward=-1, terminated=False, penalties=0
# Retraining on mini-batch at episode 7
# Episode 7, Timestep 21: action=2, reward=-1, terminated=False, penalties=0
# Episode 7, Timestep 22: action=2, reward=-1, terminated=False, penalties=0
# Episode 7, Timestep 23: action=2, reward=-1, terminated=False, penalties=0
# Episode 7, Timestep 24: action=2, reward=-1, terminated=False, penalties=0
# Episode 7, Timestep 25: action=2, reward=-1, terminated=False, penalties=0
# Episode 7, Timestep 26: action=2, reward=-1, terminated=False, penalties=0
# Episode 7, Timestep 27: action=2, reward=-1, terminated=False, penalties=0
# Episode 7, Timestep 28: action=2, reward=-1, terminated=False, penalties=0
# Episode 7, Timestep 29: action=2, reward=-1, terminated=False, penalties=0
# Episode 7, Timestep 30: action=2, reward=-1, terminated=False, penalties=0
# Retraining on mini-batch at episode 7
# Episode 7, Timestep 31: action=2, reward=-1, terminated=False, penalties=0
# Episode 7, Timestep 32: action=2, reward=-1, terminated=False, penalties=0
# Episode 7, Timestep 33: action=2, reward=-1, terminated=False, penalties=0
# Episode 7, Timestep 34: action=2, reward=-1, terminated=False, penalties=0
# Episode 7, Timestep 35: action=2, reward=-1, terminated=False, penalties=0
# Episode 7, Timestep 36: action=2, reward=-1, terminated=False, penalties=0
# Episode 7, Timestep 37: action=2, reward=-1, terminated=False, penalties=0
# Episode 7, Timestep 38: action=2, reward=-1, terminated=False, penalties=0
# Episode 7, Timestep 39: action=2, reward=-1, terminated=False, penalties=0
# Episode 7, Timestep 40: action=4, reward=-10, terminated=False, penalties=1
# Retraining on mini-batch at episode 7
# Training Episodes:   7%|▋         | 7/100 [03:47<54:41, 35.28s/it]
# Episode 8, Timestep 1: action=3, reward=-1, terminated=False, penalties=0
# Episode 8, Timestep 2: action=3, reward=-1, terminated=False, penalties=0
# Episode 8, Timestep 3: action=3, reward=-1, terminated=False, penalties=0
# Episode 8, Timestep 4: action=4, reward=-1, terminated=False, penalties=0
# Episode 8, Timestep 5: action=3, reward=-1, terminated=False, penalties=0
# Episode 8, Timestep 6: action=3, reward=-1, terminated=False, penalties=0
# Episode 8, Timestep 7: action=3, reward=-1, terminated=False, penalties=0
# Episode 8, Timestep 8: action=3, reward=-1, terminated=False, penalties=0
# Episode 8, Timestep 9: action=3, reward=-1, terminated=False, penalties=0
# Episode 8, Timestep 10: action=3, reward=-1, terminated=False, penalties=0
# Retraining on mini-batch at episode 8
# Episode 8, Timestep 11: action=2, reward=-1, terminated=False, penalties=0
# Episode 8, Timestep 12: action=2, reward=-1, terminated=False, penalties=0
# Episode 8, Timestep 13: action=2, reward=-1, terminated=False, penalties=0
# Episode 8, Timestep 14: action=2, reward=-1, terminated=False, penalties=0
# Episode 8, Timestep 15: action=2, reward=-1, terminated=False, penalties=0
# Episode 8, Timestep 16: action=2, reward=-1, terminated=False, penalties=0
# Episode 8, Timestep 17: action=2, reward=-1, terminated=False, penalties=0
# Episode 8, Timestep 18: action=0, reward=-1, terminated=False, penalties=0
# Episode 8, Timestep 19: action=5, reward=-1, terminated=False, penalties=0
# Episode 8, Timestep 20: action=2, reward=-1, terminated=False, penalties=0
# Retraining on mini-batch at episode 8
# Episode 8, Timestep 21: action=1, reward=-1, terminated=False, penalties=0
# Episode 8, Timestep 22: action=0, reward=-1, terminated=False, penalties=0
# Episode 8, Timestep 23: action=1, reward=-1, terminated=False, penalties=0
# Episode 8, Timestep 24: action=0, reward=-1, terminated=False, penalties=0
# Episode 8, Timestep 25: action=1, reward=-1, terminated=False, penalties=0
# Episode 8, Timestep 26: action=0, reward=-1, terminated=False, penalties=0
# Episode 8, Timestep 27: action=1, reward=-1, terminated=False, penalties=0
# Episode 8, Timestep 28: action=0, reward=-1, terminated=False, penalties=0
# Episode 8, Timestep 29: action=1, reward=-1, terminated=False, penalties=0
# Episode 8, Timestep 30: action=0, reward=-1, terminated=False, penalties=0
# Retraining on mini-batch at episode 8
# Episode 8, Timestep 31: action=4, reward=-1, terminated=False, penalties=0
# Episode 8, Timestep 32: action=1, reward=-1, terminated=False, penalties=0
# Episode 8, Timestep 33: action=3, reward=-1, terminated=False, penalties=0
# Episode 8, Timestep 34: action=3, reward=-1, terminated=False, penalties=0
# Episode 8, Timestep 35: action=0, reward=-1, terminated=False, penalties=0
# Episode 8, Timestep 36: action=1, reward=-1, terminated=False, penalties=0
# Episode 8, Timestep 37: action=3, reward=-1, terminated=False, penalties=0
# Episode 8, Timestep 38: action=3, reward=-1, terminated=False, penalties=0
# Episode 8, Timestep 39: action=3, reward=-1, terminated=False, penalties=0
# Episode 8, Timestep 40: action=3, reward=-1, terminated=False, penalties=0
# Retraining on mini-batch at episode 8
# Training Episodes:   8%|▊         | 8/100 [04:21<53:11, 34.69s/it]
# Episode 9, Timestep 1: action=0, reward=-1, terminated=False, penalties=0
# Episode 9, Timestep 2: action=0, reward=-1, terminated=False, penalties=0
# Episode 9, Timestep 3: action=0, reward=-1, terminated=False, penalties=0
# Episode 9, Timestep 4: action=2, reward=-1, terminated=False, penalties=0
# Episode 9, Timestep 5: action=0, reward=-1, terminated=False, penalties=0
# Episode 9, Timestep 6: action=0, reward=-1, terminated=False, penalties=0
# Episode 9, Timestep 7: action=1, reward=-1, terminated=False, penalties=0
# Episode 9, Timestep 8: action=0, reward=-1, terminated=False, penalties=0
# Episode 9, Timestep 9: action=0, reward=-1, terminated=False, penalties=0
# Episode 9, Timestep 10: action=0, reward=-1, terminated=False, penalties=0
# Retraining on mini-batch at episode 9
# Episode 9, Timestep 11: action=0, reward=-1, terminated=False, penalties=0
# Episode 9, Timestep 12: action=0, reward=-1, terminated=False, penalties=0
# Episode 9, Timestep 13: action=0, reward=-1, terminated=False, penalties=0
# Episode 9, Timestep 14: action=0, reward=-1, terminated=False, penalties=0
# Episode 9, Timestep 15: action=0, reward=-1, terminated=False, penalties=0
# Episode 9, Timestep 16: action=0, reward=-1, terminated=False, penalties=0
# Episode 9, Timestep 17: action=0, reward=-1, terminated=False, penalties=0
# Episode 9, Timestep 18: action=0, reward=-1, terminated=False, penalties=0
# Episode 9, Timestep 19: action=0, reward=-1, terminated=False, penalties=0
# Episode 9, Timestep 20: action=1, reward=-1, terminated=False, penalties=0
# Retraining on mini-batch at episode 9
# Episode 9, Timestep 21: action=3, reward=-1, terminated=False, penalties=0
# Episode 9, Timestep 22: action=3, reward=-1, terminated=False, penalties=0
# Episode 9, Timestep 23: action=3, reward=-1, terminated=False, penalties=0
# Episode 9, Timestep 24: action=3, reward=-1, terminated=False, penalties=0
# Episode 9, Timestep 25: action=3, reward=-1, terminated=False, penalties=0
# Episode 9, Timestep 26: action=3, reward=-1, terminated=False, penalties=0
# Episode 9, Timestep 27: action=3, reward=-1, terminated=False, penalties=0
# Episode 9, Timestep 28: action=3, reward=-1, terminated=False, penalties=0
# Episode 9, Timestep 29: action=3, reward=-1, terminated=False, penalties=0
# Episode 9, Timestep 30: action=2, reward=-1, terminated=False, penalties=0
# Retraining on mini-batch at episode 9
# Episode 9, Timestep 31: action=3, reward=-1, terminated=False, penalties=0
# Episode 9, Timestep 32: action=2, reward=-1, terminated=False, penalties=0
# Episode 9, Timestep 33: action=3, reward=-1, terminated=False, penalties=0
# Episode 9, Timestep 34: action=2, reward=-1, terminated=False, penalties=0
# Episode 9, Timestep 35: action=3, reward=-1, terminated=False, penalties=0
# Episode 9, Timestep 36: action=2, reward=-1, terminated=False, penalties=0
# Episode 9, Timestep 37: action=3, reward=-1, terminated=False, penalties=0
# Episode 9, Timestep 38: action=4, reward=-10, terminated=False, penalties=1
# Episode 9, Timestep 39: action=2, reward=-1, terminated=False, penalties=1
# Episode 9, Timestep 40: action=3, reward=-1, terminated=False, penalties=1
# Retraining on mini-batch at episode 9
# Training Episodes:   9%|▉         | 9/100 [04:58<53:44, 35.43s/it]
# Episode 10, Timestep 1: action=0, reward=-1, terminated=False, penalties=0
# Episode 10, Timestep 2: action=0, reward=-1, terminated=False, penalties=0
# Episode 10, Timestep 3: action=0, reward=-1, terminated=False, penalties=0
# Episode 10, Timestep 4: action=0, reward=-1, terminated=False, penalties=0
# Episode 10, Timestep 5: action=1, reward=-1, terminated=False, penalties=0
# Episode 10, Timestep 6: action=0, reward=-1, terminated=False, penalties=0
# Episode 10, Timestep 7: action=0, reward=-1, terminated=False, penalties=0
# Episode 10, Timestep 8: action=0, reward=-1, terminated=False, penalties=0
# Episode 10, Timestep 9: action=0, reward=-1, terminated=False, penalties=0
# Episode 10, Timestep 10: action=0, reward=-1, terminated=False, penalties=0
# Retraining on mini-batch at episode 10
# Episode 10, Timestep 11: action=0, reward=-1, terminated=False, penalties=0
# Episode 10, Timestep 12: action=0, reward=-1, terminated=False, penalties=0
# Episode 10, Timestep 13: action=0, reward=-1, terminated=False, penalties=0
# Episode 10, Timestep 14: action=0, reward=-1, terminated=False, penalties=0
# Episode 10, Timestep 15: action=0, reward=-1, terminated=False, penalties=0
# Episode 10, Timestep 16: action=0, reward=-1, terminated=False, penalties=0
# Episode 10, Timestep 17: action=0, reward=-1, terminated=False, penalties=0
# Episode 10, Timestep 18: action=0, reward=-1, terminated=False, penalties=0
# Episode 10, Timestep 19: action=5, reward=-10, terminated=False, penalties=1
# Episode 10, Timestep 20: action=2, reward=-1, terminated=False, penalties=1
# Retraining on mini-batch at episode 10
# Episode 10, Timestep 21: action=0, reward=-1, terminated=False, penalties=1
# Episode 10, Timestep 22: action=0, reward=-1, terminated=False, penalties=1
# Episode 10, Timestep 23: action=0, reward=-1, terminated=False, penalties=1
# Episode 10, Timestep 24: action=0, reward=-1, terminated=False, penalties=1
# Episode 10, Timestep 25: action=0, reward=-1, terminated=False, penalties=1
# Episode 10, Timestep 26: action=0, reward=-1, terminated=False, penalties=1
# Episode 10, Timestep 27: action=0, reward=-1, terminated=False, penalties=1
# Episode 10, Timestep 28: action=0, reward=-1, terminated=False, penalties=1
# Episode 10, Timestep 29: action=0, reward=-1, terminated=False, penalties=1
# Episode 10, Timestep 30: action=0, reward=-1, terminated=False, penalties=1
# Retraining on mini-batch at episode 10
# Episode 10, Timestep 31: action=0, reward=-1, terminated=False, penalties=1
# Episode 10, Timestep 32: action=0, reward=-1, terminated=False, penalties=1
# Episode 10, Timestep 33: action=0, reward=-1, terminated=False, penalties=1
# Episode 10, Timestep 34: action=0, reward=-1, terminated=False, penalties=1
# Episode 10, Timestep 35: action=0, reward=-1, terminated=False, penalties=1
# Episode 10, Timestep 36: action=4, reward=-10, terminated=False, penalties=2
# Episode 10, Timestep 37: action=0, reward=-1, terminated=False, penalties=2
# Episode 10, Timestep 38: action=0, reward=-1, terminated=False, penalties=2
# Episode 10, Timestep 39: action=0, reward=-1, terminated=False, penalties=2
# Episode 10, Timestep 40: action=2, reward=-1, terminated=False, penalties=2
# Retraining on mini-batch at episode 10
# Training Episodes:  10%|█         | 10/100 [05:33<52:58, 35.32s/it]
# Episode 11, Timestep 1: action=4, reward=-10, terminated=False, penalties=1
# Episode 11, Timestep 2: action=1, reward=-1, terminated=False, penalties=1
# Episode 11, Timestep 3: action=0, reward=-1, terminated=False, penalties=1
# Episode 11, Timestep 4: action=1, reward=-1, terminated=False, penalties=1
# Episode 11, Timestep 5: action=0, reward=-1, terminated=False, penalties=1
# Episode 11, Timestep 6: action=1, reward=-1, terminated=False, penalties=1
# Episode 11, Timestep 7: action=0, reward=-1, terminated=False, penalties=1
# Episode 11, Timestep 8: action=1, reward=-1, terminated=False, penalties=1
# Episode 11, Timestep 9: action=0, reward=-1, terminated=False, penalties=1
# Episode 11, Timestep 10: action=1, reward=-1, terminated=False, penalties=1
# Retraining on mini-batch at episode 11
# Episode 11, Timestep 11: action=0, reward=-1, terminated=False, penalties=1
# Episode 11, Timestep 12: action=2, reward=-1, terminated=False, penalties=1
# Episode 11, Timestep 13: action=2, reward=-1, terminated=False, penalties=1
# Episode 11, Timestep 14: action=2, reward=-1, terminated=False, penalties=1
# Episode 11, Timestep 15: action=2, reward=-1, terminated=False, penalties=1
# Episode 11, Timestep 16: action=3, reward=-1, terminated=False, penalties=1
# Episode 11, Timestep 17: action=2, reward=-1, terminated=False, penalties=1
# Episode 11, Timestep 18: action=2, reward=-1, terminated=False, penalties=1
# Episode 11, Timestep 19: action=2, reward=-1, terminated=False, penalties=1
# Episode 11, Timestep 20: action=2, reward=-1, terminated=False, penalties=1
# Retraining on mini-batch at episode 11
# Episode 11, Timestep 21: action=2, reward=-1, terminated=False, penalties=1
# Episode 11, Timestep 22: action=2, reward=-1, terminated=False, penalties=1
# Episode 11, Timestep 23: action=2, reward=-1, terminated=False, penalties=1
# Episode 11, Timestep 24: action=2, reward=-1, terminated=False, penalties=1
# Episode 11, Timestep 25: action=2, reward=-1, terminated=False, penalties=1
# Episode 11, Timestep 26: action=2, reward=-1, terminated=False, penalties=1
# Episode 11, Timestep 27: action=2, reward=-1, terminated=False, penalties=1
# Episode 11, Timestep 28: action=2, reward=-1, terminated=False, penalties=1
# Episode 11, Timestep 29: action=2, reward=-1, terminated=False, penalties=1
# Episode 11, Timestep 30: action=2, reward=-1, terminated=False, penalties=1
# Retraining on mini-batch at episode 11
# Episode 11, Timestep 31: action=2, reward=-1, terminated=False, penalties=1
# Episode 11, Timestep 32: action=2, reward=-1, terminated=False, penalties=1
# Episode 11, Timestep 33: action=2, reward=-1, terminated=False, penalties=1
# Episode 11, Timestep 34: action=2, reward=-1, terminated=False, penalties=1
# Episode 11, Timestep 35: action=2, reward=-1, terminated=False, penalties=1
# Episode 11, Timestep 36: action=2, reward=-1, terminated=False, penalties=1
# Episode 11, Timestep 37: action=2, reward=-1, terminated=False, penalties=1
# Episode 11, Timestep 38: action=0, reward=-1, terminated=False, penalties=1
# Episode 11, Timestep 39: action=2, reward=-1, terminated=False, penalties=1
# Episode 11, Timestep 40: action=2, reward=-1, terminated=False, penalties=1
# Retraining on mini-batch at episode 11
# Training Episodes:  11%|█         | 11/100 [06:09<52:39, 35.51s/it]
# Episode 12, Timestep 1: action=2, reward=-1, terminated=False, penalties=0
# Episode 12, Timestep 2: action=2, reward=-1, terminated=False, penalties=0
# Episode 12, Timestep 3: action=0, reward=-1, terminated=False, penalties=0
# Episode 12, Timestep 4: action=0, reward=-1, terminated=False, penalties=0
# Episode 12, Timestep 5: action=2, reward=-1, terminated=False, penalties=0
# Episode 12, Timestep 6: action=2, reward=-1, terminated=False, penalties=0
# Episode 12, Timestep 7: action=2, reward=-1, terminated=False, penalties=0
# Episode 12, Timestep 8: action=2, reward=-1, terminated=False, penalties=0
# Episode 12, Timestep 9: action=2, reward=-1, terminated=False, penalties=0
# Episode 12, Timestep 10: action=2, reward=-1, terminated=False, penalties=0
# Retraining on mini-batch at episode 12
# Episode 12, Timestep 11: action=2, reward=-1, terminated=False, penalties=0
# Episode 12, Timestep 12: action=1, reward=-1, terminated=False, penalties=0
# Episode 12, Timestep 13: action=5, reward=-10, terminated=False, penalties=1
# Episode 12, Timestep 14: action=3, reward=-1, terminated=False, penalties=1
# Episode 12, Timestep 15: action=1, reward=-1, terminated=False, penalties=1
# Episode 12, Timestep 16: action=2, reward=-1, terminated=False, penalties=1
# Episode 12, Timestep 17: action=1, reward=-1, terminated=False, penalties=1
# Episode 12, Timestep 18: action=1, reward=-1, terminated=False, penalties=1
# Episode 12, Timestep 19: action=2, reward=-1, terminated=False, penalties=1
# Episode 12, Timestep 20: action=1, reward=-1, terminated=False, penalties=1
# Retraining on mini-batch at episode 12
# Episode 12, Timestep 21: action=2, reward=-1, terminated=False, penalties=1
# Episode 12, Timestep 22: action=2, reward=-1, terminated=False, penalties=1
# Episode 12, Timestep 23: action=2, reward=-1, terminated=False, penalties=1
# Episode 12, Timestep 24: action=2, reward=-1, terminated=False, penalties=1
# Episode 12, Timestep 25: action=2, reward=-1, terminated=False, penalties=1
# Episode 12, Timestep 26: action=2, reward=-1, terminated=False, penalties=1
# Episode 12, Timestep 27: action=2, reward=-1, terminated=False, penalties=1
# Episode 12, Timestep 28: action=2, reward=-1, terminated=False, penalties=1
# Episode 12, Timestep 29: action=2, reward=-1, terminated=False, penalties=1
# Episode 12, Timestep 30: action=2, reward=-1, terminated=False, penalties=1
# Retraining on mini-batch at episode 12
# Episode 12, Timestep 31: action=1, reward=-1, terminated=False, penalties=1
# Episode 12, Timestep 32: action=0, reward=-1, terminated=False, penalties=1
# Episode 12, Timestep 33: action=0, reward=-1, terminated=False, penalties=1
# Episode 12, Timestep 34: action=0, reward=-1, terminated=False, penalties=1
# Episode 12, Timestep 35: action=0, reward=-1, terminated=False, penalties=1
# Episode 12, Timestep 36: action=0, reward=-1, terminated=False, penalties=1
# Episode 12, Timestep 37: action=0, reward=-1, terminated=False, penalties=1
# Episode 12, Timestep 38: action=0, reward=-1, terminated=False, penalties=1
# Episode 12, Timestep 39: action=0, reward=-1, terminated=False, penalties=1
# Episode 12, Timestep 40: action=0, reward=-1, terminated=False, penalties=1
# Retraining on mini-batch at episode 12
# Training Episodes:  12%|█▏        | 12/100 [06:45<52:16, 35.64s/it]
# Episode 13, Timestep 1: action=3, reward=-1, terminated=False, penalties=0
# Episode 13, Timestep 2: action=3, reward=-1, terminated=False, penalties=0
# Episode 13, Timestep 3: action=3, reward=-1, terminated=False, penalties=0
# Episode 13, Timestep 4: action=3, reward=-1, terminated=False, penalties=0
# Episode 13, Timestep 5: action=3, reward=-1, terminated=False, penalties=0
# Episode 13, Timestep 6: action=3, reward=-1, terminated=False, penalties=0
# Episode 13, Timestep 7: action=3, reward=-1, terminated=False, penalties=0
# Episode 13, Timestep 8: action=3, reward=-1, terminated=False, penalties=0
# Episode 13, Timestep 9: action=3, reward=-1, terminated=False, penalties=0
# Episode 13, Timestep 10: action=3, reward=-1, terminated=False, penalties=0
# Retraining on mini-batch at episode 13
# Episode 13, Timestep 11: action=1, reward=-1, terminated=False, penalties=0
# Episode 13, Timestep 12: action=1, reward=-1, terminated=False, penalties=0
# Episode 13, Timestep 13: action=1, reward=-1, terminated=False, penalties=0
# Episode 13, Timestep 14: action=1, reward=-1, terminated=False, penalties=0
# Episode 13, Timestep 15: action=1, reward=-1, terminated=False, penalties=0
# Episode 13, Timestep 16: action=1, reward=-1, terminated=False, penalties=0
# Episode 13, Timestep 17: action=0, reward=-1, terminated=False, penalties=0
# Episode 13, Timestep 18: action=1, reward=-1, terminated=False, penalties=0
# Episode 13, Timestep 19: action=1, reward=-1, terminated=False, penalties=0
# Episode 13, Timestep 20: action=1, reward=-1, terminated=False, penalties=0
# Retraining on mini-batch at episode 13
# Episode 13, Timestep 21: action=1, reward=-1, terminated=False, penalties=0
# Episode 13, Timestep 22: action=1, reward=-1, terminated=False, penalties=0
# Episode 13, Timestep 23: action=1, reward=-1, terminated=False, penalties=0
# Episode 13, Timestep 24: action=1, reward=-1, terminated=False, penalties=0
# Episode 13, Timestep 25: action=1, reward=-1, terminated=False, penalties=0
# Episode 13, Timestep 26: action=1, reward=-1, terminated=False, penalties=0
# Episode 13, Timestep 27: action=1, reward=-1, terminated=False, penalties=0
# Episode 13, Timestep 28: action=1, reward=-1, terminated=False, penalties=0
# Episode 13, Timestep 29: action=1, reward=-1, terminated=False, penalties=0
# Episode 13, Timestep 30: action=1, reward=-1, terminated=False, penalties=0
# Retraining on mini-batch at episode 13
# Episode 13, Timestep 31: action=4, reward=-10, terminated=False, penalties=1
# Episode 13, Timestep 32: action=4, reward=-10, terminated=False, penalties=2
# Episode 13, Timestep 33: action=4, reward=-10, terminated=False, penalties=3
# Episode 13, Timestep 34: action=4, reward=-10, terminated=False, penalties=4
# Episode 13, Timestep 35: action=4, reward=-10, terminated=False, penalties=5
# Episode 13, Timestep 36: action=4, reward=-10, terminated=False, penalties=6
# Episode 13, Timestep 37: action=4, reward=-10, terminated=False, penalties=7
# Episode 13, Timestep 38: action=4, reward=-10, terminated=False, penalties=8
# Episode 13, Timestep 39: action=4, reward=-10, terminated=False, penalties=9
# Episode 13, Timestep 40: action=4, reward=-10, terminated=False, penalties=10
# Retraining on mini-batch at episode 13
# Training Episodes:  13%|█▎        | 13/100 [07:20<51:20, 35.40s/it]
# Episode 14, Timestep 1: action=0, reward=-1, terminated=False, penalties=0
# Episode 14, Timestep 2: action=3, reward=-1, terminated=False, penalties=0
# Episode 14, Timestep 3: action=3, reward=-1, terminated=False, penalties=0
# Episode 14, Timestep 4: action=3, reward=-1, terminated=False, penalties=0
# Episode 14, Timestep 5: action=3, reward=-1, terminated=False, penalties=0
# Episode 14, Timestep 6: action=3, reward=-1, terminated=False, penalties=0
# Episode 14, Timestep 7: action=3, reward=-1, terminated=False, penalties=0
# Episode 14, Timestep 8: action=3, reward=-1, terminated=False, penalties=0
# Episode 14, Timestep 9: action=3, reward=-1, terminated=False, penalties=0
# Episode 14, Timestep 10: action=3, reward=-1, terminated=False, penalties=0
# Retraining on mini-batch at episode 14
# Episode 14, Timestep 11: action=3, reward=-1, terminated=False, penalties=0
# Episode 14, Timestep 12: action=3, reward=-1, terminated=False, penalties=0
# Episode 14, Timestep 13: action=3, reward=-1, terminated=False, penalties=0
# Episode 14, Timestep 14: action=3, reward=-1, terminated=False, penalties=0
# Episode 14, Timestep 15: action=3, reward=-1, terminated=False, penalties=0
# Episode 14, Timestep 16: action=3, reward=-1, terminated=False, penalties=0
# Episode 14, Timestep 17: action=3, reward=-1, terminated=False, penalties=0
# Episode 14, Timestep 18: action=3, reward=-1, terminated=False, penalties=0
# Episode 14, Timestep 19: action=3, reward=-1, terminated=False, penalties=0
# Episode 14, Timestep 20: action=3, reward=-1, terminated=False, penalties=0
# Retraining on mini-batch at episode 14
# Episode 14, Timestep 21: action=0, reward=-1, terminated=False, penalties=0
# Episode 14, Timestep 22: action=2, reward=-1, terminated=False, penalties=0
# Episode 14, Timestep 23: action=1, reward=-1, terminated=False, penalties=0
# Episode 14, Timestep 24: action=1, reward=-1, terminated=False, penalties=0
# Episode 14, Timestep 25: action=1, reward=-1, terminated=False, penalties=0
# Episode 14, Timestep 26: action=1, reward=-1, terminated=False, penalties=0
# Episode 14, Timestep 27: action=1, reward=-1, terminated=False, penalties=0
# Episode 14, Timestep 28: action=1, reward=-1, terminated=False, penalties=0
# Episode 14, Timestep 29: action=1, reward=-1, terminated=False, penalties=0
# Episode 14, Timestep 30: action=1, reward=-1, terminated=False, penalties=0
# Retraining on mini-batch at episode 14
# Episode 14, Timestep 31: action=0, reward=-1, terminated=False, penalties=0
# Episode 14, Timestep 32: action=0, reward=-1, terminated=False, penalties=0
# Episode 14, Timestep 33: action=0, reward=-1, terminated=False, penalties=0
# Episode 14, Timestep 34: action=0, reward=-1, terminated=False, penalties=0
# Episode 14, Timestep 35: action=0, reward=-1, terminated=False, penalties=0
# Episode 14, Timestep 36: action=1, reward=-1, terminated=False, penalties=0
# Episode 14, Timestep 37: action=0, reward=-1, terminated=False, penalties=0
# Episode 14, Timestep 38: action=0, reward=-1, terminated=False, penalties=0
# Episode 14, Timestep 39: action=0, reward=-1, terminated=False, penalties=0
# Episode 14, Timestep 40: action=0, reward=-1, terminated=False, penalties=0
# Retraining on mini-batch at episode 14
# Training Episodes:  14%|█▍        | 14/100 [07:58<51:49, 36.16s/it]
# Episode 15, Timestep 1: action=3, reward=-1, terminated=False, penalties=0
# Episode 15, Timestep 2: action=2, reward=-1, terminated=False, penalties=0
# Episode 15, Timestep 3: action=3, reward=-1, terminated=False, penalties=0
# Episode 15, Timestep 4: action=2, reward=-1, terminated=False, penalties=0
# Episode 15, Timestep 5: action=3, reward=-1, terminated=False, penalties=0
# Episode 15, Timestep 6: action=2, reward=-1, terminated=False, penalties=0
# Episode 15, Timestep 7: action=3, reward=-1, terminated=False, penalties=0
# Episode 15, Timestep 8: action=2, reward=-1, terminated=False, penalties=0
# Episode 15, Timestep 9: action=3, reward=-1, terminated=False, penalties=0
# Episode 15, Timestep 10: action=2, reward=-1, terminated=False, penalties=0
# Retraining on mini-batch at episode 15
# Episode 15, Timestep 11: action=1, reward=-1, terminated=False, penalties=0
# Episode 15, Timestep 12: action=1, reward=-1, terminated=False, penalties=0
# Episode 15, Timestep 13: action=1, reward=-1, terminated=False, penalties=0
# Episode 15, Timestep 14: action=1, reward=-1, terminated=False, penalties=0
# Episode 15, Timestep 15: action=1, reward=-1, terminated=False, penalties=0
# Episode 15, Timestep 16: action=1, reward=-1, terminated=False, penalties=0
# Episode 15, Timestep 17: action=1, reward=-1, terminated=False, penalties=0
# Episode 15, Timestep 18: action=1, reward=-1, terminated=False, penalties=0
# Episode 15, Timestep 19: action=1, reward=-1, terminated=False, penalties=0
# Episode 15, Timestep 20: action=1, reward=-1, terminated=False, penalties=0
# Retraining on mini-batch at episode 15
# Episode 15, Timestep 21: action=1, reward=-1, terminated=False, penalties=0
# Episode 15, Timestep 22: action=1, reward=-1, terminated=False, penalties=0
# Episode 15, Timestep 23: action=1, reward=-1, terminated=False, penalties=0
# Episode 15, Timestep 24: action=1, reward=-1, terminated=False, penalties=0
# Episode 15, Timestep 25: action=3, reward=-1, terminated=False, penalties=0
# Episode 15, Timestep 26: action=1, reward=-1, terminated=False, penalties=0
# Episode 15, Timestep 27: action=1, reward=-1, terminated=False, penalties=0
# Episode 15, Timestep 28: action=1, reward=-1, terminated=False, penalties=0
# Episode 15, Timestep 29: action=1, reward=-1, terminated=False, penalties=0
# Episode 15, Timestep 30: action=1, reward=-1, terminated=False, penalties=0
# Retraining on mini-batch at episode 15
# Episode 15, Timestep 31: action=1, reward=-1, terminated=False, penalties=0
# Episode 15, Timestep 32: action=1, reward=-1, terminated=False, penalties=0
# Episode 15, Timestep 33: action=1, reward=-1, terminated=False, penalties=0
# Episode 15, Timestep 34: action=0, reward=-1, terminated=False, penalties=0
# Episode 15, Timestep 35: action=1, reward=-1, terminated=False, penalties=0
# ...
# Evaluation Episode 96, Timestep 24: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 96, Timestep 25: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 96, Timestep 26: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 96, Timestep 27: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 96, Timestep 28: action=2, reward=-1, terminated=False, penalties=0
# Evaluation Episode 96, Timestep 29: action=3, reward=-1, terminated=False, penalties=0
# Evaluation Episode 96, Timestep 30: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 96, Timestep 31: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 96, Timestep 32: action=3, reward=-1, terminated=False, penalties=0
# Evaluation Episode 96, Timestep 33: action=4, reward=-10, terminated=False, penalties=1
# Evaluation Episode 96, Timestep 34: action=1, reward=-1, terminated=False, penalties=1
# Evaluation Episode 96, Timestep 35: action=1, reward=-1, terminated=False, penalties=1
# Evaluation Episode 96, Timestep 36: action=1, reward=-1, terminated=False, penalties=1
# Evaluation Episode 96, Timestep 37: action=1, reward=-1, terminated=False, penalties=1
# Evaluation Episode 96, Timestep 38: action=1, reward=-1, terminated=False, penalties=1
# Evaluation Episode 96, Timestep 39: action=1, reward=-1, terminated=False, penalties=1
# Evaluation Episodes:  96%|█████████▌| 96/100 [05:02<00:12,  3.09s/it]
# Evaluation Episode 96, Timestep 40: action=1, reward=-1, terminated=False, penalties=1
# Evaluation Episode 97, Timestep 1: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 97, Timestep 2: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 97, Timestep 3: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 97, Timestep 4: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 97, Timestep 5: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 97, Timestep 6: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 97, Timestep 7: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 97, Timestep 8: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 97, Timestep 9: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 97, Timestep 10: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 97, Timestep 11: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 97, Timestep 12: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 97, Timestep 13: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 97, Timestep 14: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 97, Timestep 15: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 97, Timestep 16: action=2, reward=-1, terminated=False, penalties=0
# Evaluation Episode 97, Timestep 17: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 97, Timestep 18: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 97, Timestep 19: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 97, Timestep 20: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 97, Timestep 21: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 97, Timestep 22: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 97, Timestep 23: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 97, Timestep 24: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 97, Timestep 25: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 97, Timestep 26: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 97, Timestep 27: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 97, Timestep 28: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 97, Timestep 29: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 97, Timestep 30: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 97, Timestep 31: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 97, Timestep 32: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 97, Timestep 33: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 97, Timestep 34: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 97, Timestep 35: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 97, Timestep 36: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 97, Timestep 37: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 97, Timestep 38: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 97, Timestep 39: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episodes:  97%|█████████▋| 97/100 [05:05<00:09,  3.05s/it]
# Evaluation Episode 97, Timestep 40: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 98, Timestep 1: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 98, Timestep 2: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 98, Timestep 3: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 98, Timestep 4: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 98, Timestep 5: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 98, Timestep 6: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 98, Timestep 7: action=4, reward=-10, terminated=False, penalties=1
# Evaluation Episode 98, Timestep 8: action=1, reward=-1, terminated=False, penalties=1
# Evaluation Episode 98, Timestep 9: action=1, reward=-1, terminated=False, penalties=1
# Evaluation Episode 98, Timestep 10: action=1, reward=-1, terminated=False, penalties=1
# Evaluation Episode 98, Timestep 11: action=1, reward=-1, terminated=False, penalties=1
# Evaluation Episode 98, Timestep 12: action=1, reward=-1, terminated=False, penalties=1
# Evaluation Episode 98, Timestep 13: action=3, reward=-1, terminated=False, penalties=1
# Evaluation Episode 98, Timestep 14: action=1, reward=-1, terminated=False, penalties=1
# Evaluation Episode 98, Timestep 15: action=1, reward=-1, terminated=False, penalties=1
# Evaluation Episode 98, Timestep 16: action=1, reward=-1, terminated=False, penalties=1
# Evaluation Episode 98, Timestep 17: action=1, reward=-1, terminated=False, penalties=1
# Evaluation Episode 98, Timestep 18: action=1, reward=-1, terminated=False, penalties=1
# Evaluation Episode 98, Timestep 19: action=1, reward=-1, terminated=False, penalties=1
# Evaluation Episode 98, Timestep 20: action=1, reward=-1, terminated=False, penalties=1
# Evaluation Episode 98, Timestep 21: action=1, reward=-1, terminated=False, penalties=1
# Evaluation Episode 98, Timestep 22: action=1, reward=-1, terminated=False, penalties=1
# Evaluation Episode 98, Timestep 23: action=1, reward=-1, terminated=False, penalties=1
# Evaluation Episode 98, Timestep 24: action=1, reward=-1, terminated=False, penalties=1
# Evaluation Episode 98, Timestep 25: action=1, reward=-1, terminated=False, penalties=1
# Evaluation Episode 98, Timestep 26: action=1, reward=-1, terminated=False, penalties=1
# Evaluation Episode 98, Timestep 27: action=1, reward=-1, terminated=False, penalties=1
# Evaluation Episode 98, Timestep 28: action=1, reward=-1, terminated=False, penalties=1
# Evaluation Episode 98, Timestep 29: action=1, reward=-1, terminated=False, penalties=1
# Evaluation Episode 98, Timestep 30: action=1, reward=-1, terminated=False, penalties=1
# Evaluation Episode 98, Timestep 31: action=1, reward=-1, terminated=False, penalties=1
# Evaluation Episode 98, Timestep 32: action=5, reward=-10, terminated=False, penalties=2
# Evaluation Episode 98, Timestep 33: action=1, reward=-1, terminated=False, penalties=2
# Evaluation Episode 98, Timestep 34: action=1, reward=-1, terminated=False, penalties=2
# Evaluation Episode 98, Timestep 35: action=1, reward=-1, terminated=False, penalties=2
# Evaluation Episode 98, Timestep 36: action=1, reward=-1, terminated=False, penalties=2
# Evaluation Episodes:  98%|█████████▊| 98/100 [05:08<00:05,  3.00s/it]
# Evaluation Episode 98, Timestep 37: action=1, reward=-1, terminated=False, penalties=2
# Evaluation Episode 98, Timestep 38: action=1, reward=-1, terminated=False, penalties=2
# Evaluation Episode 98, Timestep 39: action=1, reward=-1, terminated=False, penalties=2
# Evaluation Episode 98, Timestep 40: action=1, reward=-1, terminated=False, penalties=2
# Evaluation Episode 99, Timestep 1: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 99, Timestep 2: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 99, Timestep 3: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 99, Timestep 4: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 99, Timestep 5: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 99, Timestep 6: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 99, Timestep 7: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 99, Timestep 8: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 99, Timestep 9: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 99, Timestep 10: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 99, Timestep 11: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 99, Timestep 12: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 99, Timestep 13: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 99, Timestep 14: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 99, Timestep 15: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 99, Timestep 16: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 99, Timestep 17: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 99, Timestep 18: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 99, Timestep 19: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 99, Timestep 20: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 99, Timestep 21: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 99, Timestep 22: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 99, Timestep 23: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 99, Timestep 24: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 99, Timestep 25: action=2, reward=-1, terminated=False, penalties=0
# Evaluation Episode 99, Timestep 26: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 99, Timestep 27: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 99, Timestep 28: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 99, Timestep 29: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 99, Timestep 30: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 99, Timestep 31: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 99, Timestep 32: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 99, Timestep 33: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 99, Timestep 34: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 99, Timestep 35: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 99, Timestep 36: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 99, Timestep 37: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 99, Timestep 38: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 99, Timestep 39: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episodes:  99%|█████████▉| 99/100 [05:11<00:03,  3.21s/it]
# Evaluation Episode 99, Timestep 40: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 100, Timestep 1: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 100, Timestep 2: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 100, Timestep 3: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 100, Timestep 4: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 100, Timestep 5: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 100, Timestep 6: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 100, Timestep 7: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 100, Timestep 8: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 100, Timestep 9: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 100, Timestep 10: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 100, Timestep 11: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 100, Timestep 12: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 100, Timestep 13: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 100, Timestep 14: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 100, Timestep 15: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 100, Timestep 16: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 100, Timestep 17: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 100, Timestep 18: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 100, Timestep 19: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 100, Timestep 20: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 100, Timestep 21: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 100, Timestep 22: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 100, Timestep 23: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 100, Timestep 24: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 100, Timestep 25: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 100, Timestep 26: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 100, Timestep 27: action=1, reward=-1, terminated=False, penalties=0
# Evaluation Episode 100, Timestep 28: action=5, reward=-10, terminated=False, penalties=1
# Evaluation Episode 100, Timestep 29: action=1, reward=-1, terminated=False, penalties=1
# Evaluation Episode 100, Timestep 30: action=1, reward=-1, terminated=False, penalties=1
# Evaluation Episode 100, Timestep 31: action=1, reward=-1, terminated=False, penalties=1
# Evaluation Episode 100, Timestep 32: action=1, reward=-1, terminated=False, penalties=1
# Evaluation Episode 100, Timestep 33: action=1, reward=-1, terminated=False, penalties=1
# Evaluation Episode 100, Timestep 34: action=1, reward=-1, terminated=False, penalties=1
# Evaluation Episode 100, Timestep 35: action=1, reward=-1, terminated=False, penalties=1
# Evaluation Episode 100, Timestep 36: action=1, reward=-1, terminated=False, penalties=1
# Evaluation Episode 100, Timestep 37: action=1, reward=-1, terminated=False, penalties=1
# Evaluation Episode 100, Timestep 38: action=1, reward=-1, terminated=False, penalties=1
# Evaluation Episodes: 100%|██████████| 100/100 [05:14<00:00,  3.15s/it]
# Evaluation Episode 100, Timestep 39: action=1, reward=-1, terminated=False, penalties=1
# Evaluation Episode 100, Timestep 40: action=1, reward=-1, terminated=False, penalties=1
# Deep Q-Learning Method:
# Average number of penalties per episode: 1.4
# Average number of timesteps per trip: 40.0
# Average rewards per move: -0.03290155440414508
# Time to train: 3528.5490431785583 seconds

# %%
sm_data = {
    "Metric": ["Average Penalties", "Average Timesteps", "Average Rewards per Move", "Training Execution Time (seconds)"],
    "Sample Method": [64.2, 195.88, -772.42, 0.8409316539764404]
}

ql_data = {
    "Metric": ["Average Penalties", "Average Timesteps", "Average Rewards per Move", "Training Execution Time (seconds)"],
    "Q-Learning": [0.48125, 15.89639, 0.046793606804738715, 69.6101667881012]
}

sar_data = {
    "Metric": ["Average Penalties", "Average Timesteps", "Average Rewards per Move", "Training Execution Time (seconds)"],
    "SARSA": [0.90008, 28.31204, -0.5942176334709375, 120.70162725448608]
}

dql_data = {
    "Metric": ["Average Penalties", "Average Timesteps", "Average Rewards per Move", "Training Execution Time (seconds)"],
    "Deep Q-Learning": [1.4, 40.0, -0.03290155440414508, 3528.5490431785583]
}

# Create DataFrames
sm_df = pd.DataFrame(sm_data)
ql_df = pd.DataFrame(ql_data)
sarsa_df = pd.DataFrame(sar_data)
dql_df = pd.DataFrame(dql_data)

# Merge DataFrames
summary_df = pd.merge(sm_df, ql_df, on="Metric")
summary_df = pd.merge(summary_df, sarsa_df, on="Metric")
summary_df = pd.merge(summary_df, dql_df, on="Metric")
summary_df = summary_df.round(2)

print("Summary DataFrame:")
summary_df
# Out:
# Summary DataFrame:
#                               Metric  Sample Method  Q-Learning   SARSA  \
# 0                  Average Penalties          64.20        0.48    0.90
# 1                  Average Timesteps         195.88       15.90   28.31
# 2           Average Rewards per Move        -772.42        0.05   -0.59
# 3  Training Execution Time (seconds)           0.84       69.61  120.70
#
#    Deep Q-Learning
# 0             1.40
# 1            40.00
# 2            -0.03
# 3          3528.55
